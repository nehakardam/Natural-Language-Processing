# %%
import json
import os
import re
import string
from collections import Counter, defaultdict

import matplotlib.pyplot as plt

from pprint import pprint as pp

plt.style.use('seaborn-whitegrid')

SPACE_SYM = '<s>'

# from bpe import Encoder

class BytePairEncoding:
    def __init__(   self, 
                    file_path,
                    space_symbol = SPACE_SYM
                ) -> None:
        
        self.space = space_symbol

        if not os.path.exists(file_path):
            print(f"Error! {file_path} does not exist!")
            return None
        
        lines = []
        with open(file_path, "r") as f:
            lines = f.readlines()
        
        # Step 0: Clean text
        sentences_list = self._clean_sentences(lines)

        # Step 1: Append, to each word, a special <s> symbol marking the end of a word
        self.vocab, space_marked_sentences_list = self._add_word_space_symbols(sentences_list)
        self.types_vocab = set()
    

    def _clean_sentences(self, sentences_list):
        # sentences_list = [s.translate(str.maketrans('', '', string.punctuation)) for s in sentences_list]
        return list(map(str.strip, sentences_list))
    

    def _add_word_space_symbols(self, sentences_list):
        modified_sentences_list = []

        for sentence in sentences_list:
            word_list = sentence.split(" ")
            tokens = [" ".join(word) + ' ' + self.space for word in word_list]
            # tokens = " ".join(word_list) + ' ' + self.space
            modified_sentences_list.append(tokens)
        
        vocab = Counter(self._flatten(modified_sentences_list))
        # vocab = Counter(modified_sentences_list)
            
        return vocab, modified_sentences_list


    def _get_pair_counts(self):
        pairs = defaultdict(int)
        for word, frequency in self.vocab.items():
            symbols = word.split()

            for i in range(1, len(symbols)):
                pairs[symbols[i-1], symbols[i]] += frequency
            
        return pairs


    def _merge_vocab(self, char_pair_to_merge, vocab):
        
        modified_vocab = {}

        bigram = re.escape(' '.join(char_pair_to_merge))
        p = re.compile(r'(?<!\S)' + bigram + r'(?!\S)')

        for word in vocab:
            # replace most frequent pair in all vocabulary
            w_out = p.sub(''.join(char_pair_to_merge), word)
            # print(''.join(char_pair_to_merge), w_out)
            modified_vocab[w_out] = vocab[word]
        
        return modified_vocab
    

    def _save_scatter_plot(self, descriptive_name, x, y):

        plt.scatter(x, y)
        plt.title('Byte-Pair Encoding Algorithm')
        plt.xlabel('Size of Type Vocabulary(x)')
        plt.ylabel('Length of training corpus (in tokens)(y)')
        plt.savefig(f'{descriptive_name}_bpe_scatterplot.png')


    def get_data_lengths(self):
        type_vocab = set()
        corpus_length = 0

        for k, v in self.vocab.items():
            merged = k.split(" ")
            type_vocab.update(merged)
            corpus_length += (len(merged) * v)
        
        self.types_vocab = self.types_vocab.union(type_vocab)
        return len(self.types_vocab), corpus_length


    def _save_information(self, descriptive_name, x, y, num_iters, merge_pairs_list):
        xx, yy = self.get_data_lengths()

        with open(f"{descriptive_name}.out", 'w') as f:
            f.write(f'Number of Iterations Completed: {num_iters}\n\n')
            f.write(f'Length of Types Vocab: {xx}\n')
            f.write(f'Frequency Sum of Types Vocab: {sum(self.char_pairs.values())}\n\n')
            f.write(f'Length of Training Vocab: {len(self.vocab)}\n')
            f.write(f'Frequency of Training Vocab: {sum(self.vocab.values())}\n')
            f.write(f'Length of Training Data Under Types: {yy}\n\n')

        with open(f"{descriptive_name}_merge_rules.out", 'w') as f:
            f.writelines([f"{item[0]}||{item[1]}\n" for item in merge_pairs_list])
        
        def remap_keys(mapping):
            return [{'key':k, 'value': v} for k, v in mapping.items()]
        
        with open(f'char_pairs_{descriptive_name}.json', 'w') as f:
            json.dump(remap_keys(self.char_pairs), f, indent=4, sort_keys=True)

        with open(f'vocab_final_{descriptive_name}.json', 'w') as f:
            json.dump(self.vocab, f, indent=4, sort_keys=True)
        
        self._save_scatter_plot(descriptive_name, x, y)


    def encode_word(self, ordered_merge_pairs_path, word):
        ordered_merge_pairs = []
        with open(ordered_merge_pairs_path, 'r') as f:
            ordered_merge_pairs = f.readlines()
        
        ordered_merge_pairs = self._clean_sentences(ordered_merge_pairs)

        word_l = self._clean_sentences([word])
        vocab, word_l = self._add_word_space_symbols(word_l)

        for pair in ordered_merge_pairs:
            pair = pair.split("||")
            vocab = self._merge_vocab(pair, vocab)
        
        return list(vocab.keys())[0].split(' ')


    def fit(self):

        with open('vocab_initial.json', 'w') as f:
            json.dump(self.vocab, f, indent=4, sort_keys=True)

        x, y = [], []
        merge_pairs_list = []

        i = 0
        is_frequency_one = False
        while True:
            i += 1

            # Step 2: Count the character pairs
            self.char_pairs = self._get_pair_counts()
            
            # Used to produce a scatter plot of the algorithm
            xx, yy = self.get_data_lengths()
            x.append(xx)
            y.append(yy)

            # Indicates we are done with fitting.
            # No more merge rules can be applied here
            if not self.char_pairs: break
            
            top_char_pair = self._get_most_frequent_bigram(self.char_pairs)
            top_pair_frequency = self.char_pairs[top_char_pair]
            merge_pairs_list.append(top_char_pair)

            # Track output
            if i % 1000: print(f"Current top pair frequency: {top_pair_frequency}")

            if top_pair_frequency == 1 and not is_frequency_one:
                self._save_information('frequency_one', x, y, i, merge_pairs_list)
                is_frequency_one = True

            self.vocab = self._merge_vocab(top_char_pair, self.vocab)
            
            # print(f"Bigram to Merge: {top_char_pair}")
            # pp(self.char_pairs)
            # pp(self.vocab)
            # print(self.get_data_lengths())
            # print(self.types_vocab)
            # print()

        self._save_information('frequency_zero', x, y, i, merge_pairs_list)


    def _get_most_frequent_bigram(self, char_pairs):
        return max(char_pairs, key=char_pairs.get)


    def _flatten(self, l: list):
        flat_list = [item for sublist in l for item in sublist]
        return flat_list


if __name__ == "__main__":
    print("A5 - NLP - Apoorv Sharma")

    bpe = BytePairEncoding("A8-data.txt")
    bpe.fit()
    
    with open(f"frequency_one.out", 'a') as f:
        f.writelines([f"{item} " for item in bpe.encode_word('frequency_one_merge_rules.out', 'Acnestis')])
# Out:
# A5 - NLP - Apoorv Sharma
# Current top pair frequency: 19877
# Current top pair frequency: 13717
# Current top pair frequency: 12039
# Current top pair frequency: 9857
# Current top pair frequency: 8639
# Current top pair frequency: 8534
# Current top pair frequency: 8047
# Current top pair frequency: 7794
# Current top pair frequency: 7668
# Current top pair frequency: 7094
# Current top pair frequency: 6178
# Current top pair frequency: 5633
# Current top pair frequency: 5302
# Current top pair frequency: 5169
# Current top pair frequency: 4748
# Current top pair frequency: 4687
# Current top pair frequency: 4556
# Current top pair frequency: 4392
# Current top pair frequency: 4379
# Current top pair frequency: 4080
# Current top pair frequency: 4031
# Current top pair frequency: 3642
# Current top pair frequency: 3553
# Current top pair frequency: 3272
# Current top pair frequency: 3188
# Current top pair frequency: 3088
# Current top pair frequency: 2862
# Current top pair frequency: 2713
# Current top pair frequency: 2685
# Current top pair frequency: 2658
# Current top pair frequency: 2648
# Current top pair frequency: 2633
# Current top pair frequency: 2377
# Current top pair frequency: 2333
# Current top pair frequency: 2304
# Current top pair frequency: 2292
# Current top pair frequency: 2218
# Current top pair frequency: 2144
# Current top pair frequency: 2024
# Current top pair frequency: 1967
# Current top pair frequency: 1899
# Current top pair frequency: 1876
# Current top pair frequency: 1852
# Current top pair frequency: 1803
# Current top pair frequency: 1764
# Current top pair frequency: 1672
# Current top pair frequency: 1671
# Current top pair frequency: 1654
# Current top pair frequency: 1567
# Current top pair frequency: 1566
# Current top pair frequency: 1555
# Current top pair frequency: 1485
# Current top pair frequency: 1384
# Current top pair frequency: 1381
# Current top pair frequency: 1343
# Current top pair frequency: 1323
# Current top pair frequency: 1310
# Current top pair frequency: 1302
# Current top pair frequency: 1300
# Current top pair frequency: 1298
# Current top pair frequency: 1262
# Current top pair frequency: 1259
# Current top pair frequency: 1162
# Current top pair frequency: 1118
# Current top pair frequency: 1110
# Current top pair frequency: 1100
# Current top pair frequency: 1097
# Current top pair frequency: 1091
# Current top pair frequency: 1075
# Current top pair frequency: 1068
# Current top pair frequency: 1060
# Current top pair frequency: 1042
# Current top pair frequency: 1038
# Current top pair frequency: 1020
# Current top pair frequency: 1007
# Current top pair frequency: 983
# Current top pair frequency: 971
# Current top pair frequency: 949
# Current top pair frequency: 934
# Current top pair frequency: 925
# Current top pair frequency: 922
# Current top pair frequency: 893
# Current top pair frequency: 877
# Current top pair frequency: 857
# Current top pair frequency: 848
# Current top pair frequency: 843
# Current top pair frequency: 837
# Current top pair frequency: 817
# Current top pair frequency: 811
# Current top pair frequency: 799
# Current top pair frequency: 791
# Current top pair frequency: 791
# Current top pair frequency: 781
# Current top pair frequency: 757
# Current top pair frequency: 752
# Current top pair frequency: 749
# Current top pair frequency: 741
# Current top pair frequency: 740
# Current top pair frequency: 729
# Current top pair frequency: 728
# Current top pair frequency: 724
# Current top pair frequency: 721
# Current top pair frequency: 715
# Current top pair frequency: 713
# Current top pair frequency: 694
# Current top pair frequency: 691
# Current top pair frequency: 670
# Current top pair frequency: 662
# Current top pair frequency: 657
# Current top pair frequency: 650
# Current top pair frequency: 648
# Current top pair frequency: 645
# Current top pair frequency: 639
# Current top pair frequency: 620
# Current top pair frequency: 620
# Current top pair frequency: 614
# Current top pair frequency: 597
# Current top pair frequency: 585
# Current top pair frequency: 585
# Current top pair frequency: 582
# Current top pair frequency: 580
# Current top pair frequency: 573
# Current top pair frequency: 565
# Current top pair frequency: 559
# Current top pair frequency: 558
# Current top pair frequency: 557
# Current top pair frequency: 556
# Current top pair frequency: 552
# Current top pair frequency: 551
# Current top pair frequency: 542
# Current top pair frequency: 534
# Current top pair frequency: 531
# Current top pair frequency: 527
# Current top pair frequency: 527
# Current top pair frequency: 522
# Current top pair frequency: 518
# Current top pair frequency: 514
# Current top pair frequency: 509
# Current top pair frequency: 499
# Current top pair frequency: 498
# Current top pair frequency: 496
# Current top pair frequency: 496
# Current top pair frequency: 495
# Current top pair frequency: 486
# Current top pair frequency: 484
# Current top pair frequency: 483
# Current top pair frequency: 478
# Current top pair frequency: 474
# Current top pair frequency: 472
# Current top pair frequency: 471
# Current top pair frequency: 468
# Current top pair frequency: 463
# Current top pair frequency: 460
# Current top pair frequency: 457
# Current top pair frequency: 456
# Current top pair frequency: 446
# Current top pair frequency: 438
# Current top pair frequency: 438
# Current top pair frequency: 433
# Current top pair frequency: 423
# Current top pair frequency: 420
# Current top pair frequency: 416
# Current top pair frequency: 415
# Current top pair frequency: 413
# Current top pair frequency: 411
# Current top pair frequency: 409
# Current top pair frequency: 408
# Current top pair frequency: 408
# Current top pair frequency: 405
# Current top pair frequency: 405
# Current top pair frequency: 400
# Current top pair frequency: 399
# Current top pair frequency: 396
# Current top pair frequency: 394
# Current top pair frequency: 393
# Current top pair frequency: 389
# Current top pair frequency: 387
# Current top pair frequency: 381
# Current top pair frequency: 380
# Current top pair frequency: 379
# Current top pair frequency: 377
# Current top pair frequency: 376
# Current top pair frequency: 370
# Current top pair frequency: 366
# Current top pair frequency: 366
# Current top pair frequency: 360
# Current top pair frequency: 357
# Current top pair frequency: 353
# Current top pair frequency: 352
# Current top pair frequency: 348
# Current top pair frequency: 344
# Current top pair frequency: 343
# Current top pair frequency: 342
# Current top pair frequency: 338
# Current top pair frequency: 337
# Current top pair frequency: 336
# Current top pair frequency: 336
# Current top pair frequency: 334
# Current top pair frequency: 333
# Current top pair frequency: 330
# Current top pair frequency: 327
# Current top pair frequency: 322
# Current top pair frequency: 322
# Current top pair frequency: 319
# Current top pair frequency: 318
# Current top pair frequency: 317
# Current top pair frequency: 317
# Current top pair frequency: 315
# Current top pair frequency: 315
# Current top pair frequency: 312
# Current top pair frequency: 307
# Current top pair frequency: 306
# Current top pair frequency: 302
# Current top pair frequency: 298
# Current top pair frequency: 297
# Current top pair frequency: 293
# Current top pair frequency: 292
# Current top pair frequency: 288
# Current top pair frequency: 286
# Current top pair frequency: 284
# Current top pair frequency: 283
# Current top pair frequency: 283
# Current top pair frequency: 281
# Current top pair frequency: 281
# Current top pair frequency: 278
# Current top pair frequency: 274
# Current top pair frequency: 274
# Current top pair frequency: 273
# Current top pair frequency: 273
# Current top pair frequency: 272
# Current top pair frequency: 268
# Current top pair frequency: 266
# Current top pair frequency: 263
# Current top pair frequency: 261
# Current top pair frequency: 260
# Current top pair frequency: 259
# Current top pair frequency: 258
# Current top pair frequency: 256
# Current top pair frequency: 255
# Current top pair frequency: 255
# Current top pair frequency: 255
# Current top pair frequency: 254
# Current top pair frequency: 251
# Current top pair frequency: 250
# Current top pair frequency: 249
# Current top pair frequency: 249
# Current top pair frequency: 249
# Current top pair frequency: 249
# Current top pair frequency: 249
# Current top pair frequency: 248
# Current top pair frequency: 247
# Current top pair frequency: 244
# Current top pair frequency: 244
# Current top pair frequency: 242
# Current top pair frequency: 241
# Current top pair frequency: 239
# Current top pair frequency: 238
# Current top pair frequency: 235
# Current top pair frequency: 235
# Current top pair frequency: 233
# Current top pair frequency: 232
# Current top pair frequency: 230
# Current top pair frequency: 230
# Current top pair frequency: 228
# Current top pair frequency: 225
# Current top pair frequency: 223
# Current top pair frequency: 219
# Current top pair frequency: 219
# Current top pair frequency: 218
# Current top pair frequency: 218
# Current top pair frequency: 215
# Current top pair frequency: 215
# Current top pair frequency: 214
# Current top pair frequency: 214
# Current top pair frequency: 213
# Current top pair frequency: 211
# Current top pair frequency: 210
# Current top pair frequency: 209
# Current top pair frequency: 207
# Current top pair frequency: 206
# Current top pair frequency: 205
# Current top pair frequency: 204
# Current top pair frequency: 201
# Current top pair frequency: 201
# Current top pair frequency: 201
# Current top pair frequency: 199
# Current top pair frequency: 199
# Current top pair frequency: 198
# Current top pair frequency: 198
# Current top pair frequency: 196
# Current top pair frequency: 196
# Current top pair frequency: 196
# Current top pair frequency: 194
# Current top pair frequency: 194
# Current top pair frequency: 192
# Current top pair frequency: 192
# Current top pair frequency: 192
# Current top pair frequency: 192
# Current top pair frequency: 192
# Current top pair frequency: 192
# Current top pair frequency: 191
# Current top pair frequency: 189
# Current top pair frequency: 189
# Current top pair frequency: 189
# Current top pair frequency: 189
# Current top pair frequency: 189
# Current top pair frequency: 188
# Current top pair frequency: 187
# Current top pair frequency: 187
# Current top pair frequency: 187
# Current top pair frequency: 185
# Current top pair frequency: 185
# Current top pair frequency: 185
# Current top pair frequency: 185
# Current top pair frequency: 185
# Current top pair frequency: 185
# Current top pair frequency: 184
# Current top pair frequency: 184
# Current top pair frequency: 183
# Current top pair frequency: 181
# Current top pair frequency: 181
# Current top pair frequency: 181
# Current top pair frequency: 181
# Current top pair frequency: 180
# Current top pair frequency: 180
# Current top pair frequency: 178
# Current top pair frequency: 178
# Current top pair frequency: 177
# Current top pair frequency: 177
# Current top pair frequency: 175
# Current top pair frequency: 174
# Current top pair frequency: 174
# Current top pair frequency: 174
# Current top pair frequency: 173
# Current top pair frequency: 173
# Current top pair frequency: 172
# Current top pair frequency: 172
# Current top pair frequency: 171
# Current top pair frequency: 171
# Current top pair frequency: 170
# Current top pair frequency: 169
# Current top pair frequency: 168
# Current top pair frequency: 168
# Current top pair frequency: 168
# Current top pair frequency: 167
# Current top pair frequency: 167
# Current top pair frequency: 166
# Current top pair frequency: 166
# Current top pair frequency: 166
# Current top pair frequency: 165
# Current top pair frequency: 165
# Current top pair frequency: 165
# Current top pair frequency: 164
# Current top pair frequency: 164
# Current top pair frequency: 164
# Current top pair frequency: 164
# Current top pair frequency: 163
# Current top pair frequency: 162
# Current top pair frequency: 161
# Current top pair frequency: 161
# Current top pair frequency: 160
# Current top pair frequency: 160
# Current top pair frequency: 160
# Current top pair frequency: 160
# Current top pair frequency: 159
# Current top pair frequency: 158
# Current top pair frequency: 158
# Current top pair frequency: 157
# Current top pair frequency: 157
# Current top pair frequency: 156
# Current top pair frequency: 156
# Current top pair frequency: 155
# Current top pair frequency: 155
# Current top pair frequency: 155
# Current top pair frequency: 155
# Current top pair frequency: 154
# Current top pair frequency: 154
# Current top pair frequency: 153
# Current top pair frequency: 152
# Current top pair frequency: 151
# Current top pair frequency: 150
# Current top pair frequency: 150
# Current top pair frequency: 149
# Current top pair frequency: 149
# Current top pair frequency: 149
# Current top pair frequency: 149
# Current top pair frequency: 149
# Current top pair frequency: 149
# Current top pair frequency: 148
# Current top pair frequency: 147
# Current top pair frequency: 147
# Current top pair frequency: 147
# Current top pair frequency: 147
# Current top pair frequency: 147
# Current top pair frequency: 147
# Current top pair frequency: 147
# Current top pair frequency: 146
# Current top pair frequency: 146
# Current top pair frequency: 146
# Current top pair frequency: 145
# Current top pair frequency: 145
# Current top pair frequency: 145
# Current top pair frequency: 145
# Current top pair frequency: 145
# Current top pair frequency: 144
# Current top pair frequency: 144
# Current top pair frequency: 143
# Current top pair frequency: 143
# Current top pair frequency: 142
# Current top pair frequency: 142
# Current top pair frequency: 142
# Current top pair frequency: 142
# Current top pair frequency: 141
# Current top pair frequency: 140
# Current top pair frequency: 139
# Current top pair frequency: 139
# Current top pair frequency: 139
# Current top pair frequency: 138
# Current top pair frequency: 138
# Current top pair frequency: 138
# Current top pair frequency: 138
# Current top pair frequency: 137
# Current top pair frequency: 136
# Current top pair frequency: 136
# Current top pair frequency: 136
# Current top pair frequency: 136
# Current top pair frequency: 135
# Current top pair frequency: 134
# Current top pair frequency: 134
# Current top pair frequency: 133
# Current top pair frequency: 133
# Current top pair frequency: 133
# Current top pair frequency: 132
# Current top pair frequency: 132
# Current top pair frequency: 132
# Current top pair frequency: 131
# Current top pair frequency: 131
# Current top pair frequency: 131
# Current top pair frequency: 130
# Current top pair frequency: 130
# Current top pair frequency: 130
# Current top pair frequency: 130
# Current top pair frequency: 129
# Current top pair frequency: 129
# Current top pair frequency: 129
# Current top pair frequency: 128
# Current top pair frequency: 128
# Current top pair frequency: 128
# Current top pair frequency: 127
# Current top pair frequency: 126
# Current top pair frequency: 126
# Current top pair frequency: 126
# Current top pair frequency: 126
# Current top pair frequency: 126
# Current top pair frequency: 126
# Current top pair frequency: 125
# Current top pair frequency: 125
# Current top pair frequency: 125
# Current top pair frequency: 124
# Current top pair frequency: 124
# Current top pair frequency: 123
# Current top pair frequency: 123
# Current top pair frequency: 123
# Current top pair frequency: 122
# Current top pair frequency: 122
# Current top pair frequency: 122
# Current top pair frequency: 121
# Current top pair frequency: 121
# Current top pair frequency: 121
# Current top pair frequency: 121
# Current top pair frequency: 121
# Current top pair frequency: 119
# Current top pair frequency: 119
# Current top pair frequency: 119
# Current top pair frequency: 118
# Current top pair frequency: 118
# Current top pair frequency: 118
# Current top pair frequency: 118
# Current top pair frequency: 117
# Current top pair frequency: 117
# Current top pair frequency: 117
# Current top pair frequency: 117
# Current top pair frequency: 117
# Current top pair frequency: 116
# Current top pair frequency: 116
# Current top pair frequency: 116
# Current top pair frequency: 116
# Current top pair frequency: 115
# Current top pair frequency: 115
# Current top pair frequency: 115
# Current top pair frequency: 115
# Current top pair frequency: 115
# Current top pair frequency: 114
# Current top pair frequency: 114
# Current top pair frequency: 114
# Current top pair frequency: 113
# Current top pair frequency: 113
# Current top pair frequency: 113
# Current top pair frequency: 113
# Current top pair frequency: 113
# Current top pair frequency: 113
# Current top pair frequency: 113
# Current top pair frequency: 112
# Current top pair frequency: 112
# Current top pair frequency: 112
# Current top pair frequency: 111
# Current top pair frequency: 110
# Current top pair frequency: 110
# Current top pair frequency: 110
# Current top pair frequency: 110
# Current top pair frequency: 110
# Current top pair frequency: 110
# Current top pair frequency: 109
# Current top pair frequency: 109
# Current top pair frequency: 109
# Current top pair frequency: 109
# Current top pair frequency: 109
# Current top pair frequency: 109
# Current top pair frequency: 108
# Current top pair frequency: 108
# Current top pair frequency: 107
# Current top pair frequency: 107
# Current top pair frequency: 107
# Current top pair frequency: 106
# Current top pair frequency: 106
# Current top pair frequency: 106
# Current top pair frequency: 106
# Current top pair frequency: 105
# Current top pair frequency: 105
# Current top pair frequency: 105
# Current top pair frequency: 105
# Current top pair frequency: 104
# Current top pair frequency: 104
# Current top pair frequency: 104
# Current top pair frequency: 104
# Current top pair frequency: 104
# Current top pair frequency: 103
# Current top pair frequency: 103
# Current top pair frequency: 103
# Current top pair frequency: 103
# Current top pair frequency: 103
# Current top pair frequency: 102
# Current top pair frequency: 102
# Current top pair frequency: 102
# Current top pair frequency: 102
# Current top pair frequency: 102
# Current top pair frequency: 101
# Current top pair frequency: 101
# Current top pair frequency: 101
# Current top pair frequency: 101
# Current top pair frequency: 100
# Current top pair frequency: 100
# Current top pair frequency: 100
# Current top pair frequency: 100
# Current top pair frequency: 99
# Current top pair frequency: 99
# Current top pair frequency: 99
# Current top pair frequency: 99
# Current top pair frequency: 99
# Current top pair frequency: 98
# Current top pair frequency: 98
# Current top pair frequency: 98
# Current top pair frequency: 98
# Current top pair frequency: 97
# Current top pair frequency: 97
# Current top pair frequency: 97
# Current top pair frequency: 96
# Current top pair frequency: 96
# Current top pair frequency: 96
# Current top pair frequency: 96
# Current top pair frequency: 96
# Current top pair frequency: 95
# Current top pair frequency: 95
# Current top pair frequency: 94
# Current top pair frequency: 94
# Current top pair frequency: 94
# Current top pair frequency: 94
# Current top pair frequency: 94
# Current top pair frequency: 94
# Current top pair frequency: 94
# Current top pair frequency: 93
# Current top pair frequency: 93
# Current top pair frequency: 93
# Current top pair frequency: 93
# Current top pair frequency: 93
# Current top pair frequency: 93
# Current top pair frequency: 92
# Current top pair frequency: 92
# Current top pair frequency: 92
# Current top pair frequency: 92
# Current top pair frequency: 92
# Current top pair frequency: 91
# Current top pair frequency: 91
# Current top pair frequency: 91
# Current top pair frequency: 91
# Current top pair frequency: 91
# Current top pair frequency: 91
# Current top pair frequency: 91
# Current top pair frequency: 91
# Current top pair frequency: 90
# Current top pair frequency: 90
# Current top pair frequency: 89
# Current top pair frequency: 89
# Current top pair frequency: 89
# Current top pair frequency: 89
# Current top pair frequency: 89
# Current top pair frequency: 89
# Current top pair frequency: 89
# Current top pair frequency: 88
# Current top pair frequency: 88
# Current top pair frequency: 88
# Current top pair frequency: 88
# Current top pair frequency: 88
# Current top pair frequency: 88
# Current top pair frequency: 88
# Current top pair frequency: 87
# Current top pair frequency: 87
# Current top pair frequency: 87
# Current top pair frequency: 87
# Current top pair frequency: 87
# Current top pair frequency: 86
# Current top pair frequency: 86
# Current top pair frequency: 86
# Current top pair frequency: 86
# Current top pair frequency: 86
# Current top pair frequency: 86
# Current top pair frequency: 86
# Current top pair frequency: 86
# Current top pair frequency: 85
# Current top pair frequency: 85
# Current top pair frequency: 85
# Current top pair frequency: 85
# Current top pair frequency: 85
# Current top pair frequency: 85
# Current top pair frequency: 84
# Current top pair frequency: 84
# Current top pair frequency: 84
# Current top pair frequency: 84
# Current top pair frequency: 84
# Current top pair frequency: 83
# Current top pair frequency: 83
# Current top pair frequency: 83
# Current top pair frequency: 83
# Current top pair frequency: 83
# Current top pair frequency: 83
# Current top pair frequency: 83
# Current top pair frequency: 83
# Current top pair frequency: 82
# Current top pair frequency: 82
# Current top pair frequency: 82
# Current top pair frequency: 82
# Current top pair frequency: 82
# Current top pair frequency: 82
# Current top pair frequency: 82
# Current top pair frequency: 81
# Current top pair frequency: 81
# Current top pair frequency: 81
# Current top pair frequency: 81
# Current top pair frequency: 81
# Current top pair frequency: 81
# Current top pair frequency: 81
# Current top pair frequency: 81
# Current top pair frequency: 80
# Current top pair frequency: 80
# Current top pair frequency: 80
# Current top pair frequency: 80
# Current top pair frequency: 80
# Current top pair frequency: 80
# Current top pair frequency: 80
# Current top pair frequency: 79
# Current top pair frequency: 79
# Current top pair frequency: 79
# Current top pair frequency: 79
# Current top pair frequency: 78
# Current top pair frequency: 78
# Current top pair frequency: 78
# Current top pair frequency: 78
# Current top pair frequency: 78
# Current top pair frequency: 78
# Current top pair frequency: 78
# Current top pair frequency: 77
# Current top pair frequency: 77
# Current top pair frequency: 77
# Current top pair frequency: 77
# Current top pair frequency: 77
# Current top pair frequency: 77
# Current top pair frequency: 77
# Current top pair frequency: 76
# Current top pair frequency: 76
# Current top pair frequency: 76
# Current top pair frequency: 76
# Current top pair frequency: 76
# Current top pair frequency: 76
# Current top pair frequency: 76
# Current top pair frequency: 76
# Current top pair frequency: 76
# Current top pair frequency: 76
# Current top pair frequency: 75
# Current top pair frequency: 75
# Current top pair frequency: 75
# Current top pair frequency: 75
# Current top pair frequency: 75
# Current top pair frequency: 75
# Current top pair frequency: 75
# Current top pair frequency: 75
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 74
# Current top pair frequency: 73
# Current top pair frequency: 73
# Current top pair frequency: 73
# Current top pair frequency: 73
# Current top pair frequency: 73
# Current top pair frequency: 73
# Current top pair frequency: 73
# Current top pair frequency: 73
# Current top pair frequency: 73
# Current top pair frequency: 72
# Current top pair frequency: 72
# Current top pair frequency: 72
# Current top pair frequency: 72
# Current top pair frequency: 72
# Current top pair frequency: 72
# Current top pair frequency: 72
# Current top pair frequency: 72
# Current top pair frequency: 72
# Current top pair frequency: 72
# Current top pair frequency: 71
# Current top pair frequency: 71
# Current top pair frequency: 71
# Current top pair frequency: 71
# Current top pair frequency: 71
# Current top pair frequency: 71
# Current top pair frequency: 71
# Current top pair frequency: 71
# Current top pair frequency: 71
# Current top pair frequency: 70
# Current top pair frequency: 70
# Current top pair frequency: 70
# Current top pair frequency: 70
# Current top pair frequency: 70
# Current top pair frequency: 70
# Current top pair frequency: 70
# Current top pair frequency: 70
# Current top pair frequency: 69
# Current top pair frequency: 69
# Current top pair frequency: 69
# Current top pair frequency: 69
# Current top pair frequency: 69
# Current top pair frequency: 69
# Current top pair frequency: 69
# Current top pair frequency: 69
# Current top pair frequency: 68
# Current top pair frequency: 68
# Current top pair frequency: 68
# Current top pair frequency: 68
# Current top pair frequency: 68
# Current top pair frequency: 68
# Current top pair frequency: 68
# Current top pair frequency: 68
# Current top pair frequency: 67
# Current top pair frequency: 67
# Current top pair frequency: 67
# Current top pair frequency: 67
# Current top pair frequency: 67
# Current top pair frequency: 67
# Current top pair frequency: 67
# Current top pair frequency: 67
# Current top pair frequency: 66
# Current top pair frequency: 66
# Current top pair frequency: 66
# Current top pair frequency: 66
# Current top pair frequency: 66
# Current top pair frequency: 66
# Current top pair frequency: 66
# Current top pair frequency: 66
# Current top pair frequency: 65
# Current top pair frequency: 65
# Current top pair frequency: 65
# Current top pair frequency: 65
# Current top pair frequency: 65
# Current top pair frequency: 65
# Current top pair frequency: 65
# Current top pair frequency: 65
# Current top pair frequency: 65
# Current top pair frequency: 65
# Current top pair frequency: 65
# Current top pair frequency: 65
# Current top pair frequency: 65
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 64
# Current top pair frequency: 63
# Current top pair frequency: 63
# Current top pair frequency: 63
# Current top pair frequency: 63
# Current top pair frequency: 63
# Current top pair frequency: 63
# Current top pair frequency: 63
# Current top pair frequency: 62
# Current top pair frequency: 62
# Current top pair frequency: 62
# Current top pair frequency: 62
# Current top pair frequency: 62
# Current top pair frequency: 62
# Current top pair frequency: 62
# Current top pair frequency: 62
# Current top pair frequency: 62
# Current top pair frequency: 62
# Current top pair frequency: 62
# Current top pair frequency: 62
# Current top pair frequency: 62
# Current top pair frequency: 62
# Current top pair frequency: 62
# Current top pair frequency: 62
# Current top pair frequency: 61
# Current top pair frequency: 61
# Current top pair frequency: 61
# Current top pair frequency: 61
# Current top pair frequency: 61
# Current top pair frequency: 61
# Current top pair frequency: 61
# Current top pair frequency: 61
# Current top pair frequency: 61
# Current top pair frequency: 61
# Current top pair frequency: 61
# Current top pair frequency: 61
# Current top pair frequency: 60
# Current top pair frequency: 60
# Current top pair frequency: 60
# Current top pair frequency: 60
# Current top pair frequency: 60
# Current top pair frequency: 60
# Current top pair frequency: 60
# Current top pair frequency: 60
# Current top pair frequency: 60
# Current top pair frequency: 60
# Current top pair frequency: 60
# Current top pair frequency: 60
# Current top pair frequency: 59
# Current top pair frequency: 59
# Current top pair frequency: 59
# Current top pair frequency: 59
# Current top pair frequency: 59
# Current top pair frequency: 59
# Current top pair frequency: 59
# Current top pair frequency: 59
# Current top pair frequency: 59
# Current top pair frequency: 59
# Current top pair frequency: 59
# Current top pair frequency: 58
# Current top pair frequency: 58
# Current top pair frequency: 58
# Current top pair frequency: 58
# Current top pair frequency: 58
# Current top pair frequency: 58
# Current top pair frequency: 58
# Current top pair frequency: 58
# Current top pair frequency: 58
# Current top pair frequency: 58
# Current top pair frequency: 57
# Current top pair frequency: 57
# Current top pair frequency: 57
# Current top pair frequency: 57
# Current top pair frequency: 57
# Current top pair frequency: 57
# Current top pair frequency: 57
# Current top pair frequency: 57
# Current top pair frequency: 57
# Current top pair frequency: 56
# Current top pair frequency: 56
# Current top pair frequency: 56
# Current top pair frequency: 56
# Current top pair frequency: 56
# Current top pair frequency: 56
# Current top pair frequency: 56
# Current top pair frequency: 56
# Current top pair frequency: 56
# Current top pair frequency: 56
# Current top pair frequency: 56
# Current top pair frequency: 56
# Current top pair frequency: 56
# Current top pair frequency: 56
# Current top pair frequency: 55
# Current top pair frequency: 55
# Current top pair frequency: 55
# Current top pair frequency: 55
# Current top pair frequency: 55
# Current top pair frequency: 55
# Current top pair frequency: 55
# Current top pair frequency: 55
# Current top pair frequency: 55
# Current top pair frequency: 55
# Current top pair frequency: 55
# Current top pair frequency: 55
# Current top pair frequency: 55
# Current top pair frequency: 54
# Current top pair frequency: 54
# Current top pair frequency: 54
# Current top pair frequency: 54
# Current top pair frequency: 54
# Current top pair frequency: 54
# Current top pair frequency: 54
# Current top pair frequency: 54
# Current top pair frequency: 54
# Current top pair frequency: 54
# Current top pair frequency: 54
# Current top pair frequency: 54
# Current top pair frequency: 54
# Current top pair frequency: 53
# Current top pair frequency: 53
# Current top pair frequency: 53
# Current top pair frequency: 53
# Current top pair frequency: 53
# Current top pair frequency: 53
# Current top pair frequency: 53
# Current top pair frequency: 53
# Current top pair frequency: 53
# Current top pair frequency: 53
# Current top pair frequency: 53
# Current top pair frequency: 53
# Current top pair frequency: 53
# Current top pair frequency: 53
# Current top pair frequency: 53
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 52
# Current top pair frequency: 51
# Current top pair frequency: 51
# Current top pair frequency: 51
# Current top pair frequency: 51
# Current top pair frequency: 51
# Current top pair frequency: 51
# Current top pair frequency: 51
# Current top pair frequency: 51
# Current top pair frequency: 51
# Current top pair frequency: 51
# Current top pair frequency: 51
# Current top pair frequency: 51
# Current top pair frequency: 51
# Current top pair frequency: 51
# Current top pair frequency: 50
# Current top pair frequency: 50
# Current top pair frequency: 50
# Current top pair frequency: 50
# Current top pair frequency: 50
# Current top pair frequency: 50
# Current top pair frequency: 50
# Current top pair frequency: 50
# Current top pair frequency: 50
# Current top pair frequency: 50
# Current top pair frequency: 50
# Current top pair frequency: 50
# Current top pair frequency: 50
# Current top pair frequency: 50
# Current top pair frequency: 49
# Current top pair frequency: 49
# Current top pair frequency: 49
# Current top pair frequency: 49
# Current top pair frequency: 49
# Current top pair frequency: 49
# Current top pair frequency: 49
# Current top pair frequency: 49
# Current top pair frequency: 49
# Current top pair frequency: 49
# Current top pair frequency: 49
# Current top pair frequency: 49
# Current top pair frequency: 49
# Current top pair frequency: 49
# Current top pair frequency: 49
# Current top pair frequency: 49
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 48
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 47
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 46
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 45
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 44
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 43
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 42
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 41
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 40
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 39
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 38
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 37
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 36
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 35
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 34
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 33
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 32
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# Current top pair frequency: 31
# ...
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1
# Current top pair frequency: 1

# %%
len(types_vocab)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5c/hs39rcwx6319812pwgk7r0w40000gn/T/ipykernel_47960/3949538257.py in <module>
# ----> 1 len(types_vocab)
#
# NameError: name 'types_vocab' is not defined
